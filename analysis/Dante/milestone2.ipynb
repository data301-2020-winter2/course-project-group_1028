# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling as pdp
from scripts1.project_functions import *

# %%
sns.set_theme(font_scale=1.5, style="ticks")

# %%
df = load_and_process("../../data/raw/hour.csv")
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 1      instant      dteday  season  yr  mnth  hr  holiday  weekday
# 2            1  2011-01-01       1   0     1   0        0        6
# 3            2  2011-01-01       1   0     1   1        0        6
# 4            3  2011-01-01       1   0     1   2        0        6
# 5            4  2011-01-01       1   0     1   3        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17376    17375  2012-12-31       1   1    12  19        0        1
# 17377    17376  2012-12-31       1   1    12  20        0        1
# 17378    17377  2012-12-31       1   1    12  21        0        1
# 17379    17378  2012-12-31       1   1    12  22        0        1
# 17380    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 1      workingday  weathersit  temp   atemp   hum  windspeed  casual
# ...

# %%
df.shape
# Out:
# (17380, 17)

# %%
df.describe()
# Out:
#        instant      dteday season     yr   mnth     hr holiday weekday  \
# count    17380       17380  17380  17380  17380  17380   17380   17380
# unique   17380         732      5      3     13     25       3       8
# top      12005  2012-02-24      3      1      5     17       0       6
# freq         1          24   4496   8734   1488    730   16879    2512
#
#        workingday weathersit   temp   atemp    hum windspeed casual  \
# count       17380      17380  17380   17380  17380     17380  17380
# unique          3          5     51      66     90        31    323
# top             1          1   0.62  0.6212   0.88         0      0
# freq        11865      11413    726     988    657      2180   1581
#
#        registered    cnt
# count       17380  17380
# unique        777    870
# top             4      5
# freq          307    260

# %%
profile_report = pdp.ProfileReport(df)
profile_report
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-03-13 20:10:49.331656&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
humcasual=df.groupby(['hum'], as_index=False)['casual'].sum()
humcasual
# Out:
#      hum                                             casual
# 0      0                             3001011106410312259141
# 1   0.08                                                 16
# 2    0.1                                                 19
# 3   0.12                                                  6
# 4   0.13                                                  3
# ..   ...                                                ...
# 85  0.94  1112271411022120017311217014780111621496941200...
# 86  0.96                                                161
# 87  0.97                                                 18
# 88     1  1200033110105118143710110220151101441812332003...
# 89   hum                                             casual
#
# [90 rows x 2 columns]

# %%
order = df['hum'].value_counts(ascending=False).index
sns.countplot(y="hum",order=order ,data=df).set_title("humidity")
# Out:
# Text(0.5, 1.0, 'humidity')

# %%
sns.jointplot(data=df, x='cnt', y='weekday')

# %%
sns.displot(df, x = "temp",binwidth=1,hue="weekday",multiple = "stack",common_norm=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-288775b4c10d> in <module>
# ----> 1 __string__
#
# NameError: name '__string__' is not defined
